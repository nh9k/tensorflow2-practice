# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# **1. Inputs and Labels**

# %%
X = np.array([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = np.array([0.,1.,1.,0.])

# %% [markdown]
# # **Keras Version**

# %% [markdown]
# **2. Two dense layers**

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Dense(units=2,activation='sigmoid',input_dim=2))  # first dense layer # input 2
model.add(Dense(units=1,activation='sigmoid')) # second dense layer

# %%
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy']) # loss function and optimization
print(model.summary()) # model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2)                 6
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# binary cross entropy -> 0 or 1 output
# sgd -> stochastic gradient descent
# accuracy -> (True Positive + True Negative) / (ALL DATA)

# %% [markdown]
# **3. Train**

# %%
model.fit(X,y,epochs=50000,batch_size=4,verbose=0)

# %% [markdown]
# **4. Test**
# [0, 0], [0, 1] outputs are less than 0.5,
# [0, 1], [1, 0] outputs are greater than 0.5

# %%
print(model.predict(X,batch_size=4))
# Out:
# [[0.06541607]
#  [0.95063794]
#  [0.47529024]
#  [0.5076038 ]]

# %% [markdown]
# **5. Print dense layer's weights and bias**

# %%
print("first layer weights: ",model.layers[0].get_weights()[0])
print("first layer bias: ",model.layers[0].get_weights()[1])
print("second layer weights: ",model.layers[1].get_weights()[0])
print("second layer bias: ",model.layers[1].get_weights()[1])
# Out:
# first layer weights:  [[-5.3480225 -4.820369 ]
#  [ 3.604314  -2.9674377]]
# first layer bias:  [-2.5472095  0.739073 ]
# second layer weights:  [[ 4.597318 ]
#  [-4.3813767]]
# second layer bias:  [-0.02787821]

# %% [markdown]
# row(행) == input #
# col(열) == node #

# %% [markdown]
# # **Other Version**

# %% [markdown]
# **2. model**

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

def get_output(x):
    layer0 = model.layers[0]
    # first dense layer, first node output
    layer0_weights, layer0_bias = layer0.get_weights()
    layer0_node0_weights = np.transpose(layer0_weights)[0]
    layer0_node0_bias = layer0_bias[0]
    layer0_node0_output = sigmoid( np.dot( x, layer0_node0_weights ) + layer0_node0_bias )
    # second dense layer, second node output
    layer0_node1_weights = np.transpose(layer0_weights)[1]
    layer0_node1_bias = layer0_bias[1]
    layer0_node1_output = sigmoid( np.dot( x, layer0_node1_weights ) + layer0_node1_bias )
    # second layer output
    layer1 = model.layers[1]
    layer1_weights, layer1_bias = layer1.get_weights()
    layer1_output = sigmoid( np.dot( [layer0_node0_output, layer0_node1_output], layer1_weights ) + layer1_bias )

    print(layer1_output)

# %% [markdown]
# **3. Test**

# %%
get_output([0,0])
get_output([0,1])
get_output([1,0])
get_output([1,1])
# Out:
# 0.06541608041625925
# 0.9506379126275463
# 0.4752901863574643
# 0.5076038297785711
